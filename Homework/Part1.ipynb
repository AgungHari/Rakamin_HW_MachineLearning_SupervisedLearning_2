# %% [markdown]
# # Homework : Supervies Learning 2

# %% [markdown]
# - Nama : I Gusti Ngurah Agung Hari Vijaya Kusuma
# - Batch : 57
# - Hobi : Push rank

# %% [markdown]
# ---

# %% [markdown]
# Teknis Pengerjaan
# 1. Pekerjaan dilakukan oleh masing-masing individu
# 2. Menggunakan dataset berikut ini: Klik
# 3. File yang perlu dikumpulkan:
# <br>○ File jupyter notebook (.ipynb) yang berisi source code.
# <br>○ File laporan homework (.pdf) yang berisi rangkuman dari apa saja yang telah
# dilakukan.
# 4. Upload hasil pengerjaan melalui LMS.
# <br>○ Masukkan semua file ke dalam 1 file dengan format ZIP.
# <br>○ Nama File:
# Supervised - <Nama>.zip

# %% [markdown]
# ### Telecommunication Customers Churn Prediction
# <br>Pada task kali ini, student akan diminta untuk melakukan prediksi nih, apakah suatu <br>customer itu akan churn atau tidak. Ini sangat berguna untuk bisa membantu<br>mengidentiﬁkasi customer yang akan churn.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv(r'Telecom_Customers_Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### Kolom TotalCharges seharusnya memiliki tipe data float64 karena nilainya angka kita perbaiki dulu

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#convert kolom TotalCharges dari object menjadi float
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
#hapus baris yang null
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %% [markdown]
# ### Sekarang semua tipe data sudah sesuai, dan missing value juga sudah dibersihkan, selanjutnya cari nilai duplikat dulu

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# save cleaned data
# df.to_csv('Telecom_Customers_Churn_Cleaned.csv', index=False)

# %%
numeric_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']
categorical_cols = ['customerID','gender','SeniorCitizen','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','Churn']

print('Numerical Columns:', numeric_cols)
print('Categorical Columns:', categorical_cols)
# Out:
# Numerical Columns: ['tenure', 'MonthlyCharges', 'TotalCharges']
# Categorical Columns: ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']

# %% [markdown]
# Berdasarkan ilmu per wifian saya, saya yakin bahwa DSL itu teknologi jadul dan fiber optic teknologi gacor keduanya pasti relevan dengan churn, ayo kita buktikan dulu
#
# ---
# ## Apakah pelanggan dengan paket internet tertentu beresiko churn?

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='InternetService', hue='Churn')
plt.title('Churn vs Internet Service')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Jenis Internet Service')
plt.legend(title='Churn')
plt.show()

# %% [markdown]
# Uji statistik dulu

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table = pd.crosstab(df['InternetService'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Internet Service and Churn.")
else:
    print("There is no significant association between Internet Service and Churn.")
# Out:
# Chi-squared: 728.6956143058694, p-value: 5.831198962237274e-159, degrees of freedom: 2
# There is a significant association between Internet Service and Churn.

# %%
# Cramer v untuk mengetahui kekuatan asosiasi
from scipy.stats import chi2_contingency
def cramers_v(x, y):
    contingency_table = pd.crosstab(x, y)
    chi2 = chi2_contingency(contingency_table)[0]
    n = contingency_table.sum().sum()
    phi2 = chi2 / n
    r, k = contingency_table.shape
    return np.sqrt(phi2 / min(k - 1, r - 1))
cramer_v_value = cramers_v(df['InternetService'], df['Churn'])
print(f"Cramer's V: {cramer_v_value}")
# Out:
# Cramer's V: 0.3219093912684771

# %% [markdown]
# ## ini sesuai dengan ilmu per wifian agung wkwkw
#
# Fiber optic → modern tapi mahal → lebih rawan churn kalau pelanggan sensitif harga.
#
# DSL → murah tapi jadul → churn bisa terjadi kalau butuh speed lebih tinggi.
#
# No internet → biasanya pelanggan telepon rumah yang loyal / orang tua → churn rendah.
#
# ---

# %% [markdown]
# ## Apakah pelanggan dengan gender tertentu cendrung churn?

# %%
# Apakah pelanggan dengan gender tertentu cendrung churn?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='gender', hue='Churn')
plt.title('Churn vs Internet Service')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Gender')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table2 = pd.crosstab(df['gender'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table2)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Gender and Churn.")
else:
    print("There is no significant association between Gender and Churn.")
# Out:
# Chi-squared: 0.47545453727386294, p-value: 0.490488470706551, degrees of freedom: 1
# There is no significant association between Gender and Churn.

# %%
# Cramer v untuk mengetahui kekuatan asosiasi
cramer_v_value222 = cramers_v(df['gender'], df['Churn'])
print(f"Cramer's V: {cramer_v_value222}")
# Out:
# Cramer's V: 0.008222711767086818

# %% [markdown]
# ### dari uji statistik menunjukan fitur ini kurang relevan
# ---

# %% [markdown]
# ## Apakah pelanggan yang senior lebih cenderung churn daripada yang tidak senior?

# %%
# Apakah pelanggan yang senior lebih cenderung churn daripada yang tidak senior?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='SeniorCitizen', hue='Churn')
plt.title('Churn vs Senior Citizen')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Senior Citizen')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table3 = pd.crosstab(df['SeniorCitizen'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table3)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Senior Citizen and Churn.")
else:
    print("There is no significant association between Senior Citizen and Churn.")
# Out:
# Chi-squared: 158.4408162893713, p-value: 2.4792557203954705e-36, degrees of freedom: 1
# There is a significant association between Senior Citizen and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value2 = cramers_v(df['SeniorCitizen'], df['Churn'])
print(f"Cramer's V: {cramer_v_value2}")
# Out:
# Cramer's V: 0.15010463561752393

# %% [markdown]
# ### ternyata fitur ini masih relevan walaupun kurang kuat
# ---

# %% [markdown]
# ## Apakah memiliki pasangan atau tidak mempengaruhi churn?

# %%
# Apakah pelanggan yang memiliki partner lebih cenderung churn daripada yang tidak memiliki partner?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Partner', hue='Churn')
plt.title('Churn vs Partner')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Partner')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table4 = pd.crosstab(df['Partner'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table4)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Partner and Churn.")
else:
    print("There is no significant association between Partner and Churn.")
# Out:
# Chi-squared: 157.50315146557506, p-value: 3.97379757451591e-36, degrees of freedom: 1
# There is a significant association between Partner and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value3 = cramers_v(df['Partner'], df['Churn'])
print(f"Cramer's V: {cramer_v_value3}")
# Out:
# Cramer's V: 0.1496598111790044

# %% [markdown]
# ### ternyata fitur ini masih relevan walaupun kurang kuat
# ---

# %% [markdown]
# ## Apakah memiliki tanggungan(dependents) atau tidak mempengaruhi churn?

# %%
# Apakah pelanggan yang memiliki dependents lebih cenderung churn daripada yang tidak memiliki dependents?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Dependents', hue='Churn')
plt.title('Churn vs Dependents')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Dependents')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table5 = pd.crosstab(df['Dependents'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table5)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Dependents and Churn.")
else:
    print("There is no significant association between Dependents and Churn.")
# Out:
# Chi-squared: 186.32163933855873, p-value: 2.0196592017051303e-42, degrees of freedom: 1
# There is a significant association between Dependents and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value4 = cramers_v(df['Dependents'], df['Churn'])
print(f"Cramer's V: {cramer_v_value4}")
# Out:
# Cramer's V: 0.16277669159928557

# %% [markdown]
# ### ternyata fitur ini masih relevan walaupun kurang kuat
# ---

# %% [markdown]
# ## Apakah pelanggan yang memiliki layanan telepon atau tidak mempengaruhi churn?

# %%
# Apakah pelanggan yang memiliki layanan telepon lebih cenderung churn daripada yang tidak memiliki layanan telepon?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='PhoneService', hue='Churn')
plt.title('Churn vs Phone Service')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Phone Service')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table6 = pd.crosstab(df['PhoneService'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table6)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Phone Service and Churn.")
else:
    print("There is no significant association between Phone Service and Churn.")
# Out:
# Chi-squared: 0.8737327674431736, p-value: 0.34992398942431924, degrees of freedom: 1
# There is no significant association between Phone Service and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value5 = cramers_v(df['PhoneService'], df['Churn'])
print(f"Cramer's V: {cramer_v_value5}")
# Out:
# Cramer's V: 0.011146791573280324

# %% [markdown]
# ## ternyata fitur ini masih relevan walaupun kurang kuat
# ---

# %% [markdown]
# ## Apakah pelanggan yang memilih langganan dengan onlinesecurity churn?

# %%
# Apakah pelanggan yang memiliki onlinesecurity lebih cenderung churn daripada yang tidak memiliki online security?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='OnlineSecurity', hue='Churn')
plt.title('Churn vs Online Security')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Online Security')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table7 = pd.crosstab(df['OnlineSecurity'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table7)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Online Security and Churn.")
else:
    print("There is no significant association between Online Security and Churn.")
# Out:
# Chi-squared: 846.6773889208487, p-value: 1.4006867477839222e-184, degrees of freedom: 2
# There is a significant association between Online Security and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value6 = cramers_v(df['OnlineSecurity'], df['Churn'])
print(f"Cramer's V: {cramer_v_value6}")
# Out:
# Cramer's V: 0.3469920701082114

# %% [markdown]
# ### Fitur ini ternyata lumayan relevan terlihat dari hasil cramer v 0.3
# ---

# %% [markdown]
# ## Apakah pelanggan yang memilih langganan dengan onlinebackup churn?

# %%
# Apakah pelanggan yang memiliki online backup lebih cenderung churn daripada yang tidak memiliki online backup?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='OnlineBackup', hue='Churn')
plt.title('Churn vs Online Backup')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Online Backup')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table8 = pd.crosstab(df['OnlineBackup'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table8)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Online Backup and Churn.")
else:
    print("There is no significant association between Online Backup and Churn.")
# Out:
# Chi-squared: 599.1751847059026, p-value: 7.776099238804965e-131, degrees of freedom: 2
# There is a significant association between Online Backup and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value7 = cramers_v(df['OnlineBackup'], df['Churn'])
print(f"Cramer's V: {cramer_v_value7}")
# Out:
# Cramer's V: 0.291902273936468

# %% [markdown]
# ### Fitur ini ternyata lumayan relevan terlihat dari hasil cramer v 0.29
# ---

# %% [markdown]
# ## Apakah pelanggan yang memilih langganan dengan deviceprotection churn?

# %%
# Apakah pelanggan yang memiliki device protection lebih cenderung churn daripada yang tidak memiliki device protection?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='DeviceProtection', hue='Churn')
plt.title('Churn vs Device Protection')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Device Protection')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table9 = pd.crosstab(df['DeviceProtection'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table9)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Device Protection and Churn.")
else:
    print("There is no significant association between Device Protection and Churn.")
# Out:
# Chi-squared: 555.8803273428508, p-value: 1.9593887862403176e-121, degrees of freedom: 2
# There is a significant association between Device Protection and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value8 = cramers_v(df['DeviceProtection'], df['Churn'])
print(f"Cramer's V: {cramer_v_value8}")
# Out:
# Cramer's V: 0.28115850233148504

# %% [markdown]
# ### Fitur ini ternyata lumayan relevan terlihat dari hasil cramer v 0.28115
# ---

# %% [markdown]
# ## Apakah pelanggan yang memilih langganan dengan techsupport churn?

# %%
# Apakah pelanggan yang memiliki tech support lebih cenderung churn daripada yang tidak memiliki tech support?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='TechSupport', hue='Churn')
plt.title('Churn vs Tech Support')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Tech Support')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table10 = pd.crosstab(df['TechSupport'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table10)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Tech Support and Churn.")
else:
    print("There is no significant association between Tech Support and Churn.")
# Out:
# Chi-squared: 824.925564387502, p-value: 7.407807748843711e-180, degrees of freedom: 2
# There is a significant association between Tech Support and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value9 = cramers_v(df['TechSupport'], df['Churn'])
print(f"Cramer's V: {cramer_v_value9}")
# Out:
# Cramer's V: 0.342505815780552

# %% [markdown]
# ### Fitur ini ternyata lumayan relevan terlihat dari hasil cramer v 0.342
# ---

# %% [markdown]
# ## Apakah pelanggan yang memilih langganan dengan streamingtv churn?

# %%
# Apakah pelanggan yang memiliki streaming TV lebih cenderung churn daripada yang tidak memiliki streaming TV?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='StreamingTV', hue='Churn')
plt.title('Churn vs Streaming TV')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Streaming TV')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan  
contingency_table11 = pd.crosstab(df['StreamingTV'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table11)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Streaming TV and Churn.")
else:
    print("There is no significant association between Streaming TV and Churn.")
# Out:
# Chi-squared: 372.4565019355074, p-value: 1.324641113169159e-81, degrees of freedom: 2
# There is a significant association between Streaming TV and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value10 = cramers_v(df['StreamingTV'], df['Churn'])
print(f"Cramer's V: {cramer_v_value10}")
# Out:
# Cramer's V: 0.23014330684583634

# %% [markdown]
# ### Fitur ini ternyata lumayan relevan namun kurang kuat
# ### terlihat dari hasil cramer v 0.2
# ---

# %% [markdown]
# ## Apakah pelanggan yang memilih langganan dengan streamingmovies churn?

# %%
# Apakah pelanggan yang memiliki streaming movies lebih cenderung churn daripada yang tidak memiliki streaming movies?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='StreamingMovies', hue='Churn')
plt.title('Churn vs Streaming Movies')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Streaming Movies')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table12 = pd.crosstab(df['StreamingMovies'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table12)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Streaming Movies and Churn.")
else:
    print("There is no significant association between Streaming Movies and Churn.")
# Out:
# Chi-squared: 374.2684315732459, p-value: 5.353560421401324e-82, degrees of freedom: 2
# There is a significant association between Streaming Movies and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value11 = cramers_v(df['StreamingMovies'], df['Churn'])
print(f"Cramer's V: {cramer_v_value11}")
# Out:
# Cramer's V: 0.23070242924775253

# %% [markdown]
# ### Fitur ini ternyata lumayan relevan namun kurang kuat
# ### terlihat dari hasil cramer v 0.2
# ---

# %% [markdown]
# # Apakah pelanggan yang memilih fitur paperlessbilling churn?

# %%
# Apakah pelanggan yang menggunakan fitur paperless billing cenderung churn?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='PaperlessBilling', hue='Churn')
plt.title('Churn vs Paperless Billing')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Paperless Billing')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table13 = pd.crosstab(df['PaperlessBilling'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table13)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Paperless Billing and Churn.")
else:
    print("There is no significant association between Paperless Billing and Churn.")
# Out:
# Chi-squared: 256.87490836218717, p-value: 8.236203353962564e-58, degrees of freedom: 1
# There is a significant association between Paperless Billing and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value12 = cramers_v(df['PaperlessBilling'], df['Churn'])
print(f"Cramer's V: {cramer_v_value12}")
# Out:
# Cramer's V: 0.19112672191120977

# %% [markdown]
# #### Fitur ini ternyata lumayan relevan namun kurang kuat
# ### terlihat dari hasil cramer v 0.1
# ---

# %% [markdown]
# ## Apakah pelanggan yang memilih metode pembayaran tertentu churn?

# %%
# Apakah pelanggan yang memilih metode pembayaran tertentu cenderung churn?
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='PaymentMethod', hue='Churn')
plt.title('Churn vs Payment Method')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Payment Method')
plt.legend(title='Churn')
plt.xticks(rotation=45)
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table14 = pd.crosstab(df['PaymentMethod'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table14)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Payment Method and Churn.")
else:
    print("There is no significant association between Payment Method and Churn.")
# Out:
# Chi-squared: 645.4299001234638, p-value: 1.4263098511063342e-139, degrees of freedom: 3
# There is a significant association between Payment Method and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value13 = cramers_v(df['PaymentMethod'], df['Churn'])
print(f"Cramer's V: {cramer_v_value13}")
# Out:
# Cramer's V: 0.30295987245491557

# %% [markdown]
# #### Fitur ini ternyata lumayan relevan dan kuat
# ### terlihat dari hasil cramer v 0.3
# ---

# %% [markdown]
# ## Apakah pelanggan yang memilih multipleline tertentu churn?

# %%
## Apakah pelanggan yang memilih MultipleLines tertentu churn?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='MultipleLines', hue='Churn')
plt.title('Churn vs Multiple Lines')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Multiple Lines')
plt.legend(title='Churn')
plt.show()

# %%
# uji dengan chi 2 untuk tahu apkah signifikan
contingency_table15 = pd.crosstab(df['MultipleLines'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table15)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Multiple Lines and Churn.")
else:
    print("There is no significant association between Multiple Lines and Churn.")
# Out:
# Chi-squared: 11.271540824020612, p-value: 0.0035679273999811405, degrees of freedom: 2
# There is a significant association between Multiple Lines and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value14 = cramers_v(df['MultipleLines'], df['Churn'])
print(f"Cramer's V: {cramer_v_value14}")
# Out:
# Cramer's V: 0.040036141280711854

# %% [markdown]
# ### Fitur ini ternyata lumayan relevan namun kurang kuat
# ### terlihat dari hasil cramer v 0.3

# %% [markdown]
# ---

# %% [markdown]
# ## Apakah pelanggan yang dengan contract kerja tertentu churn?

# %%
# Apakah pelanggan yang memilih kontrak tertentu churn?
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Contract', hue='Churn')
plt.title('Churn vs Contract')
plt.ylabel('Jumlah Pelanggan')
plt.xlabel('Contract')
plt.legend(title='Churn')
plt.show()

# %%
## uji dengan chi 2 untuk tahu apkah signifikan
contingency_table16 = pd.crosstab(df['Contract'], df['Churn'])
chi2, p, dof, expected = chi2_contingency(contingency_table16)
print(f"Chi-squared: {chi2}, p-value: {p}, degrees of freedom: {dof}")
if p < 0.05:
    print("There is a significant association between Contract and Churn.")
else:
    print("There is no significant association between Contract and Churn.")
# Out:
# Chi-squared: 1179.5458287339445, p-value: 7.326182186265472e-257, degrees of freedom: 2
# There is a significant association between Contract and Churn.

# %%
# uji dengan cramer v untuk tahu kekuatan asosiasi
cramer_v_value15 = cramers_v(df['Contract'], df['Churn'])
print(f"Cramer's V: {cramer_v_value15}")
# Out:
# Cramer's V: 0.4095604189089921

# %% [markdown]
# ### `Kita sudah melihat fitur kategorikal dengan menganalisa melalui plot, chi-square, cramer v. Adapun tujuan dari analisa tersebut diantaranya, `
# 1. analisa plot membuat kita bisa melihat pola churn dari masing-masing fitur kategorikal,
# 2. chi-square test membuktikan apakah ada hubungan antara fitur kategorikal dengan churn,
# 3. cramer v memberikan nilai kekuatan hubungan antara fitur kategorikal dengan churn.
#
# #### Namun kita juga tidak ingin memasukan semua fitur kategorikal ke dalam model, karena bisa jadi fitur tersebut tidak relevan dengan churn. Oleh karena itu kita akan melakukan feature selection untuk memilih fitur kategorikal yang relevan dengan churn. Berdasarkan analisa di atas kita sudah mendapatkan chi-square dan cramer v untuk masing-masing fitur kategorikal. Kita akan memilih fitur berdasarkan chi-square tes dulu apabila terbukti signifikan, kemudian kita akan memilih fitur berdasarkan cramer v dengan cara meranking fitur berdasarkan nilai cramer v nya. Lalu hasil tersebut akan kita bandingkan dengan hasil dari selectkbest untuk melakukan feature selection.
#
# #####   `Diharapkan dengan feature selection ini kita bisa mendapatkan fitur kategorikal yang relevan dengan churn dan bisa digunakan untuk model klasifikasinya.`

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt

# --- 1) Siapkan categorical_clean -------------------------------------------
drop_featuresx = ['customerID', 'gender', 'PhoneService']
categorical_cols99 = df.select_dtypes(include=['object', 'category']).columns
categorical_clean = df[categorical_cols99].drop(columns=[c for c in drop_featuresx if c in categorical_cols])

# --- 2) Fungsi Cramer's V (dengan koreksi bias & handle NaN berpasangan) ----
def cramers_v(x: pd.Series, y: pd.Series) -> float:
    # hanya ambil pasangan yang sama-sama tidak NaN
    mask = x.notna() & y.notna()
    x_valid, y_valid = x[mask], y[mask]
    if x_valid.empty or y_valid.empty:
        return np.nan
    
    table = pd.crosstab(x_valid, y_valid)
    if table.size == 0:
        return np.nan
    
    chi2 = chi2_contingency(table, correction=False)[0]
    n = table.to_numpy().sum()
    if n == 0:
        return np.nan
    
    phi2 = chi2 / n
    r, k = table.shape
    # koreksi bias Bergsma (2003)
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    denom = min((kcorr-1), (rcorr-1))
    if denom <= 0:
        return np.nan
    return np.sqrt(phi2corr / denom)

# --- 3) Hitung matriks Cramer's V -------------------------------------------
cols = categorical_clean.columns
cv_mat = pd.DataFrame(np.nan, index=cols, columns=cols)

for i, c1 in enumerate(cols):
    for j, c2 in enumerate(cols):
        if j > i:  # hitung segitiga bawah saja (hemat waktu)
            cv = cramers_v(categorical_clean[c1], categorical_clean[c2])
            cv_mat.loc[c1, c2] = cv
            cv_mat.loc[c2, c1] = cv
        elif j == i:
            cv_mat.loc[c1, c2] = 1.0

# (opsional) urutkan kolom berdasarkan rata-rata asosiasi agar pola lebih jelas
order = cv_mat.mean().sort_values(ascending=False).index
cv_mat = cv_mat.loc[order, order]

# --- 4) Plot heatmap ---------------------------------------------------------
plt.figure(figsize=(12, 10))
mask = np.triu(np.ones_like(cv_mat, dtype=bool))  # sembunyikan segitiga atas
ax = sns.heatmap(cv_mat, annot=True, fmt=".2f", vmin=0, vmax=1,
                 cmap="coolwarm", mask=mask, cbar_kws={'label': "Cramer's V"})
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.title("Cramer's V Heatmap antar Fitur Kategorikal (categorical_clean)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
print(df[numeric_cols].describe())
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
#histogram untuk fitur monthlycharges dan total charges
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['MonthlyCharges'], bins=30, kde=True)
plt.title('Distribusi Monthly Charges')
plt.xlabel('Monthly Charges')
plt.ylabel('Frekuensi')
plt.subplot(1, 2, 2)
sns.histplot(df['TotalCharges'], bins=30, kde=True)
plt.title('Distribusi Total Charges')
plt.xlabel('Total Charges')
plt.ylabel('Frekuensi')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numeric Columns')
plt.show()

# %%
#boxplot untuk fitur monthlycharges dan total charges
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title('Boxplot Monthly Charges by Churn')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.subplot(1, 2, 2)
sns.boxplot(x='Churn', y='TotalCharges', data=df)
plt.title('Boxplot Total Charges by Churn')
plt.xlabel('Churn')
plt.ylabel('Total Charges')
plt.tight_layout()
plt.show()

# %%
#violin plot untuk fitur monthlycharges dan total charges
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.violinplot(x='Churn', y='MonthlyCharges', data=df)
plt.title('Violin Plot Monthly Charges by Churn')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.subplot(1, 2, 2)
sns.violinplot(x='Churn', y='TotalCharges', data=df)
plt.title('Violin Plot Total Charges by Churn')
plt.xlabel('Churn')
plt.ylabel('Total Charges')
plt.tight_layout()
plt.show()
